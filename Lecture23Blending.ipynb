# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img1=cv2.imread("D:\Python CV_Course\Computer-Vision-with-Python\DATA\dog_backpack.png")
img1=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2=cv2.imread("D:\Python CV_Course\Computer-Vision-with-Python\DATA\watermark_no_copy.png")
img2=cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img1.shape
# Out:
# (1401, 934, 3)

# %%
img2.shape
# Out:
# (1280, 1277, 3)

# %%
img1=cv2.resize(img1,(1200,1200))
img2=cv2.resize(img2,(1200,1200))

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
blend=cv2.addWeighted(img1,0.8,img2,0.5,0)

# %%
plt.imshow(blend)

# %%
img1=cv2.imread("D:\Python CV_Course\Computer-Vision-with-Python\DATA\dog_backpack.png")
img1=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2=cv2.imread("D:\Python CV_Course\Computer-Vision-with-Python\DATA\watermark_no_copy.png")
img2=cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img2=cv2.resize(img2,(600,600))

# %%
plt.imshow(img2)

# %%
larimg=img1
smaimg=img2
xoff=0
yoff=0
xend=xoff+smaimg.shape[1]
yend=yoff+smaimg.shape[0]

# %%
larimg[yoff:yend,xoff:xend]=smaimg

# %%
plt.imshow(larimg)
